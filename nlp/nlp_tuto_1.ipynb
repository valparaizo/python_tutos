# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, KFold
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import matplotlib
from matplotlib import pyplot as plt
# import seaborn as sns
# %matplotlib inline

# %%
data_all = pd.read_csv("./data/meilleursjeuvideo.csv")

# %%
data_all.describe()
# Out:
#                                                      Jeux  \
# count                                                 200
# unique                                                200
# top     Umineko no Naku Koro ni : Shinjitsu to Gensô n...
# freq                                                    1
#
#                                               Description Sortie   Test  \
# count                                                 197    200    200
# unique                                                197    172      3
# top     Gears of War 3 est un jeu d'action sur Xbox 36...   1993  19/20
# freq                                                    1      6    123
#
#            Avis
# count       187
# unique       41
# top     18.7/20
# freq         14

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(data_all)

# %%
X_train.describe()
# Out:
#           Jeux                                        Description Sortie  \
# count      150                                                148    150
# unique     150                                                148    134
# top     Driver  Gears of War 3 est un jeu d'action sur Xbox 36...   1993
# freq         1                                                  1      4
#
#          Test     Avis
# count     150      139
# unique      3       37
# top     19/20  18.7/20
# freq       91       12

# %%
X_test.describe()
# Out:
#                                                      Jeux  \
# count                                                  50
# unique                                                 50
# top     Umineko no Naku Koro ni : Shinjitsu to Gensô n...
# freq                                                    1
#
#                                               Description Sortie   Test  \
# count                                                  49     50     50
# unique                                                 49     46      3
# top     Tiré de la série des Final Fantasy, Theathrhyt...   1994  19/20
# freq                                                    1      3     32
#
#            Avis
# count        48
# unique       27
# top     18.3/20
# freq          4

# %%
X_train.head()
# Out:
#                                        Jeux  \
# 139  Castlevania : Order of Ecclesia sur DS
# 192                 Dungeon Keeper 2 sur PC
# 175                 Divinity : Original Sin
# 187              Virtua Fighter 4 Evolution
# 5            Kingpin : Life of Crime sur PC
#
#                                            Description            Sortie  \
# 139  Dracula refait surface alors que le clan Belmo...  27 novembre 2008
# 192  Dungeon Keeper 2 est un jeu de stratégie sorti...      Juillet 1999
# 175  Jeu de rôle au tour par tour, Divinity : Origi...      30 juin 2014
# 187  Virtua Fighter 4 Evolution est un jeu de comba...      20 juin 2003
# 5    Kingpin : Life of Crime est un jeu de tir à la...         Août 1999
#
#       Test     Avis
# 139  18/20      NaN
# 192  18/20    18/20
# 175  18/20  16.8/20
# 187  18/20  16.4/20
# 5    19/20  17.5/20

# %%
[X_train['Test'].str.split('/')[i] for i in range(len(X_train))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-d6badae62153> in <module>()
# ----> 1 [X_train['Test'].str.split('/')[i] for i in range(len(X_train))]
#
# <ipython-input-69-d6badae62153> in <listcomp>(.0)
# ----> 1 [X_train['Test'].str.split('/')[i] for i in range(len(X_train))]
#
# C:\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# C:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3101         try:
#    3102             return self._engine.get_value(s, k,
# -> 3103                                           tz=getattr(series.dtype, 'tz', None))
#    3104         except KeyError as e1:
#    3105             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1

# %%
X_train.head()
# Out:
#                                        Jeux  \
# 139  Castlevania : Order of Ecclesia sur DS
# 192                 Dungeon Keeper 2 sur PC
# 175                 Divinity : Original Sin
# 187              Virtua Fighter 4 Evolution
# 5            Kingpin : Life of Crime sur PC
#
#                                            Description            Sortie  \
# 139  Dracula refait surface alors que le clan Belmo...  27 novembre 2008
# 192  Dungeon Keeper 2 est un jeu de stratégie sorti...      Juillet 1999
# 175  Jeu de rôle au tour par tour, Divinity : Origi...      30 juin 2014
# 187  Virtua Fighter 4 Evolution est un jeu de comba...      20 juin 2003
# 5    Kingpin : Life of Crime est un jeu de tir à la...         Août 1999
#
#       Test     Avis
# 139  18/20      NaN
# 192  18/20    18/20
# 175  18/20  16.8/20
# 187  18/20  16.4/20
# 5    19/20  17.5/20
